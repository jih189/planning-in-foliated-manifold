# %%
import json
import numpy as np
from IPython.display import display, HTML
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
planner_names = [
    "MTGTaskPlanner",
    "MTGTaskPlannerWithGMM",
#     "DynamicMTGTaskPlannerWithGMM",
#     "DynamicMTGTaskPlannerWithGMM_V2",
    "DynamicMTGTaskPlannerWithGMM_25.0",
    "DynamicMTGTaskPlannerWithGMM_50.0",
#     "DynamicMTGTaskPlannerWithGMM_75.0",
    # "DynamicMTGTaskPlannerWithGMM_100.0",
    "MTGTaskPlannerWithAtlas",
#     "DynamicMTGPlannerWithAtlas",
#     "DynamicMTGPlannerWithAtlas_V2",
    "DynamicMTGPlannerWithAtlas_25.0",
    "DynamicMTGPlannerWithAtlas_50.0",
#     "DynamicMTGPlannerWithAtlas_75.0",
    # "DynamicMTGTaskPlannerWithAtlas_100.0",

]

# %%
def read_json(file_path):
    """
    Reads a json file
    """
    result_data = []
    # Open the file and load JSON data
    with open(file_path, 'r') as json_file:
        for line in json_file:
            try:
                result_data.append(json.loads(line))
            except:
                continue
    return result_data

# %%
filepaths = ["..//task_set/door/result.json"]


for file_path in filepaths:
    print(file_path)
    result_data = read_json(file_path)
    planner_stats = {
                        planner_name: {
                            'num' : 0, 
                            'num_success' : [], 
                            'motion_planning_time' : [],
                            'task_planning_time' : [],
                            'updating_time' : [],
                            'solution_length' : [],
                            'num_attempts' : [],
                            'total_planning_time' : [],
                            'set_start_and_goal_time' : [],
                        } 

                     for planner_name in planner_names
                    }

    for d in result_data:
        if d['planner_name'] in planner_stats:
            dic = planner_stats[d['planner_name']]
            dic['num'] += 1
            dic['num_success'].append(d['success'] == "true")
            if d['success'] == "true":
                dic['motion_planning_time'].append(d['motion_planning_time'])
                dic['task_planning_time'].append(d['task_planning_time'])
                dic['total_planning_time'].append(d['total_planning_time'])
                dic['updating_time'].append(d['updating_time'])
                dic['solution_length'].append(d['solution_length'])
                dic['num_attempts'].append(d['num_attempts'])
                dic['set_start_and_goal_time'].append(d['set_start_and_goal_time'])

    output_dict = []
    for planner_name in planner_names:
        stats = planner_stats[planner_name]

        current_planner_eval_dict = {}
        current_planner_eval_dict["Planner Name"] = planner_name
        current_planner_eval_dict["Total Number of Tasks"] = len(stats['num_success'])
        current_planner_eval_dict["Success Rate"] = np.mean(stats['num_success']) * 100.0
        current_planner_eval_dict["Mean Task Planning Time"] = np.mean(np.array(stats['task_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean Motion Planning Time"] = np.mean(np.array(stats['motion_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Total Planning Time"] = np.mean(np.array(stats['total_planning_time']) )
        current_planner_eval_dict["Set Start and Goal Time"] = np.mean(np.array(stats['set_start_and_goal_time']) )
        current_planner_eval_dict["Mean Update time"] = np.mean(np.array(stats['updating_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean solution length"] = np.mean(np.array(stats['solution_length']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean number of attempts"] = np.mean((np.array(stats['num_attempts'])) )
        output_dict.append(current_planner_eval_dict)
    df = pd.DataFrame(output_dict).set_index('Planner Name')

    display(df)
# Out:
# ..//task_set/door/result.json
# /home/jiaming/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jiaming/.local/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                                    Mean Motion Planning Time  \
# Planner Name
# MTGTaskPlanner                                           nan
# MTGTaskPlannerWithGMM                                    nan
# DynamicMTGTaskPlannerWithGMM_25.0                        nan
# DynamicMTGTaskPlannerWithGMM_50.0                        nan
# MTGTaskPlannerWithAtlas                                  nan
# DynamicMTGPlannerWithAtlas_25.0                          nan
# DynamicMTGPlannerWithAtlas_50.0                          nan
#
#                                    Mean Task Planning Time  Mean Update time  \
# Planner Name
# MTGTaskPlanner                                         nan               nan
# MTGTaskPlannerWithGMM                                  nan               nan
# DynamicMTGTaskPlannerWithGMM_25.0                      nan               nan
# DynamicMTGTaskPlannerWithGMM_50.0                      nan               nan
# MTGTaskPlannerWithAtlas                                nan               nan
# DynamicMTGPlannerWithAtlas_25.0                        nan               nan
# DynamicMTGPlannerWithAtlas_50.0                        nan               nan
#
#                                    Mean number of attempts  \
# Planner Name
# MTGTaskPlanner                                         nan
# MTGTaskPlannerWithGMM                                  nan
# DynamicMTGTaskPlannerWithGMM_25.0                      nan
# DynamicMTGTaskPlannerWithGMM_50.0                      nan
# MTGTaskPlannerWithAtlas                                nan
# DynamicMTGPlannerWithAtlas_25.0                        nan
# DynamicMTGPlannerWithAtlas_50.0                        nan
#
#                                    Mean solution length  \
# Planner Name
# MTGTaskPlanner                                      nan
# MTGTaskPlannerWithGMM                               nan
# DynamicMTGTaskPlannerWithGMM_25.0                   nan
# DynamicMTGTaskPlannerWithGMM_50.0                   nan
# MTGTaskPlannerWithAtlas                             nan
# DynamicMTGPlannerWithAtlas_25.0                     nan
# DynamicMTGPlannerWithAtlas_50.0                     nan
#
#                                    Set Start and Goal Time  Success Rate  \
# Planner Name
# MTGTaskPlanner                                         nan        0.0000
# MTGTaskPlannerWithGMM                                  nan        0.0000
# DynamicMTGTaskPlannerWithGMM_25.0                      nan           nan
# DynamicMTGTaskPlannerWithGMM_50.0                      nan           nan
# MTGTaskPlannerWithAtlas                                nan           nan
# DynamicMTGPlannerWithAtlas_25.0                        nan           nan
# DynamicMTGPlannerWithAtlas_50.0                        nan           nan
#
#                                    Total Number of Tasks  Total Planning Time
# Planner Name
# MTGTaskPlanner                                        50                  nan
# MTGTaskPlannerWithGMM                                 11                  nan
# DynamicMTGTaskPlannerWithGMM_25.0                      0                  nan
# DynamicMTGTaskPlannerWithGMM_50.0                      0                  nan
# MTGTaskPlannerWithAtlas                                0                  nan
# DynamicMTGPlannerWithAtlas_25.0                        0                  nan
# DynamicMTGPlannerWithAtlas_50.0                        0                  nan

# %%
filepaths = ["..//task_set/drawer/result.json"]


for file_path in filepaths:
    print(file_path)
    result_data = read_json(file_path)
    planner_stats = {
                        planner_name: {
                            'num' : 0, 
                            'num_success' : [], 
                            'motion_planning_time' : [],
                            'task_planning_time' : [],
                            'updating_time' : [],
                            'solution_length' : [],
                            'num_attempts' : [],
                            'total_planning_time' : [],
                            'set_start_and_goal_time' : [],
                        } 

                     for planner_name in planner_names
                    }

    for d in result_data:
        if d['planner_name'] in planner_stats:
            dic = planner_stats[d['planner_name']]
            dic['num'] += 1
            dic['num_success'].append(d['success'] == "true")
            if d['success'] == "true":
                dic['motion_planning_time'].append(d['motion_planning_time'])
                dic['task_planning_time'].append(d['task_planning_time'])
                dic['total_planning_time'].append(d['total_planning_time'])
                dic['updating_time'].append(d['updating_time'])
                dic['solution_length'].append(d['solution_length'])
                dic['num_attempts'].append(d['num_attempts'])
                dic['set_start_and_goal_time'].append(d['set_start_and_goal_time'])

    output_dict = []
    for planner_name in planner_names:
        stats = planner_stats[planner_name]

        current_planner_eval_dict = {}
        current_planner_eval_dict["Planner Name"] = planner_name
        current_planner_eval_dict["Total Number of Tasks"] = len(stats['num_success'])
        current_planner_eval_dict["Success Rate"] = np.mean(stats['num_success']) * 100.0
        current_planner_eval_dict["Mean Task Planning Time"] = np.mean(np.array(stats['task_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean Motion Planning Time"] = np.mean(np.array(stats['motion_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Total Planning Time"] = np.mean(np.array(stats['total_planning_time']) )
        current_planner_eval_dict["Set Start and Goal Time"] = np.mean(np.array(stats['set_start_and_goal_time']) )
        current_planner_eval_dict["Mean Update time"] = np.mean(np.array(stats['updating_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean solution length"] = np.mean(np.array(stats['solution_length']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean number of attempts"] = np.mean((np.array(stats['num_attempts'])) )
        output_dict.append(current_planner_eval_dict)
    df = pd.DataFrame(output_dict).set_index('Planner Name')

    display(df)
# Out:
# ..//task_set/drawer/result.json
# /home/jiaming/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jiaming/.local/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                                    Mean Motion Planning Time  \
# Planner Name
# MTGTaskPlanner                                           nan
# MTGTaskPlannerWithGMM                                    nan
# DynamicMTGTaskPlannerWithGMM_25.0                        nan
# DynamicMTGTaskPlannerWithGMM_50.0                        nan
# MTGTaskPlannerWithAtlas                                  nan
# DynamicMTGPlannerWithAtlas_25.0                          nan
# DynamicMTGPlannerWithAtlas_50.0                          nan
#
#                                    Mean Task Planning Time  Mean Update time  \
# Planner Name
# MTGTaskPlanner                                         nan               nan
# MTGTaskPlannerWithGMM                                  nan               nan
# DynamicMTGTaskPlannerWithGMM_25.0                      nan               nan
# DynamicMTGTaskPlannerWithGMM_50.0                      nan               nan
# MTGTaskPlannerWithAtlas                                nan               nan
# DynamicMTGPlannerWithAtlas_25.0                        nan               nan
# DynamicMTGPlannerWithAtlas_50.0                        nan               nan
#
#                                    Mean number of attempts  \
# Planner Name
# MTGTaskPlanner                                         nan
# MTGTaskPlannerWithGMM                                  nan
# DynamicMTGTaskPlannerWithGMM_25.0                      nan
# DynamicMTGTaskPlannerWithGMM_50.0                      nan
# MTGTaskPlannerWithAtlas                                nan
# DynamicMTGPlannerWithAtlas_25.0                        nan
# DynamicMTGPlannerWithAtlas_50.0                        nan
#
#                                    Mean solution length  \
# Planner Name
# MTGTaskPlanner                                      nan
# MTGTaskPlannerWithGMM                               nan
# DynamicMTGTaskPlannerWithGMM_25.0                   nan
# DynamicMTGTaskPlannerWithGMM_50.0                   nan
# MTGTaskPlannerWithAtlas                             nan
# DynamicMTGPlannerWithAtlas_25.0                     nan
# DynamicMTGPlannerWithAtlas_50.0                     nan
#
#                                    Set Start and Goal Time  Success Rate  \
# Planner Name
# MTGTaskPlanner                                         nan           nan
# MTGTaskPlannerWithGMM                                  nan           nan
# DynamicMTGTaskPlannerWithGMM_25.0                      nan           nan
# DynamicMTGTaskPlannerWithGMM_50.0                      nan           nan
# MTGTaskPlannerWithAtlas                                nan           nan
# DynamicMTGPlannerWithAtlas_25.0                        nan           nan
# DynamicMTGPlannerWithAtlas_50.0                        nan           nan
#
#                                    Total Number of Tasks  Total Planning Time
# Planner Name
# MTGTaskPlanner                                         0                  nan
# MTGTaskPlannerWithGMM                                  0                  nan
# DynamicMTGTaskPlannerWithGMM_25.0                      0                  nan
# DynamicMTGTaskPlannerWithGMM_50.0                      0                  nan
# MTGTaskPlannerWithAtlas                                0                  nan
# DynamicMTGPlannerWithAtlas_25.0                        0                  nan
# DynamicMTGPlannerWithAtlas_50.0                        0                  nan

# %%
filepaths = ["..//task_set/maze/result.json"]


for file_path in filepaths:
    print(file_path)
    result_data = read_json(file_path)
    planner_stats = {
                        planner_name: {
                            'num' : 0, 
                            'num_success' : [], 
                            'motion_planning_time' : [],
                            'task_planning_time' : [],
                            'updating_time' : [],
                            'solution_length' : [],
                            'num_attempts' : [],
                            'total_planning_time' : [],
                            'set_start_and_goal_time' : [],
                        } 

                     for planner_name in planner_names
                    }

    for d in result_data:
        if d['planner_name'] in planner_stats:
            dic = planner_stats[d['planner_name']]
            dic['num'] += 1
            dic['num_success'].append(d['success'] == "true")
            if d['success'] == "true":
                dic['motion_planning_time'].append(d['motion_planning_time'])
                dic['task_planning_time'].append(d['task_planning_time'])
                dic['total_planning_time'].append(d['total_planning_time'])
                dic['updating_time'].append(d['updating_time'])
                dic['solution_length'].append(d['solution_length'])
                dic['num_attempts'].append(d['num_attempts'])
                dic['set_start_and_goal_time'].append(d['set_start_and_goal_time'])

    output_dict = []
    for planner_name in planner_names:
        stats = planner_stats[planner_name]

        current_planner_eval_dict = {}
        current_planner_eval_dict["Planner Name"] = planner_name
        current_planner_eval_dict["Total Number of Tasks"] = len(stats['num_success'])
        current_planner_eval_dict["Success Rate"] = np.mean(stats['num_success']) * 100.0
        current_planner_eval_dict["Mean Task Planning Time"] = np.mean(np.array(stats['task_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean Motion Planning Time"] = np.mean(np.array(stats['motion_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Total Planning Time"] = np.mean(np.array(stats['total_planning_time']) )
        current_planner_eval_dict["Set Start and Goal Time"] = np.mean(np.array(stats['set_start_and_goal_time']) )
        current_planner_eval_dict["Mean Update time"] = np.mean(np.array(stats['updating_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean solution length"] = np.mean(np.array(stats['solution_length']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean number of attempts"] = np.mean((np.array(stats['num_attempts'])) )
        output_dict.append(current_planner_eval_dict)
    df = pd.DataFrame(output_dict).set_index('Planner Name')

    display(df)
# Out:
# ..//task_set/maze/result.json
#                                    Mean Motion Planning Time  \
# Planner Name
# MTGTaskPlanner                                        1.4601
# MTGTaskPlannerWithGMM                                 1.3204
# DynamicMTGTaskPlannerWithGMM_25.0                     1.2849
# DynamicMTGTaskPlannerWithGMM_50.0                     1.2430
# MTGTaskPlannerWithAtlas                               1.2535
# DynamicMTGPlannerWithAtlas_25.0                       1.2319
# DynamicMTGPlannerWithAtlas_50.0                       1.1524
#
#                                    Mean Task Planning Time  Mean Update time  \
# Planner Name
# MTGTaskPlanner                                      0.0328            0.1524
# MTGTaskPlannerWithGMM                               0.3202            0.4900
# DynamicMTGTaskPlannerWithGMM_25.0                   0.0896            0.1600
# DynamicMTGTaskPlannerWithGMM_50.0                   0.0882            0.1654
# MTGTaskPlannerWithAtlas                             0.2727            0.4723
# DynamicMTGPlannerWithAtlas_25.0                     0.0219            0.1556
# DynamicMTGPlannerWithAtlas_50.0                     0.1141            0.1799
#
#                                    Mean number of attempts  \
# Planner Name
# MTGTaskPlanner                                     19.5000
# MTGTaskPlannerWithGMM                               4.7021
# DynamicMTGTaskPlannerWithGMM_25.0                   4.1633
# DynamicMTGTaskPlannerWithGMM_50.0                   3.6122
# MTGTaskPlannerWithAtlas                             3.8889
# DynamicMTGPlannerWithAtlas_25.0                     1.8696
# DynamicMTGPlannerWithAtlas_50.0                     5.2083
#
#                                    Mean solution length  \
# Planner Name
# MTGTaskPlanner                                   3.8749
# MTGTaskPlannerWithGMM                           14.0403
# DynamicMTGTaskPlannerWithGMM_25.0               15.4046
# DynamicMTGTaskPlannerWithGMM_50.0               14.6593
# MTGTaskPlannerWithAtlas                         14.5608
# DynamicMTGPlannerWithAtlas_25.0                 16.2415
# DynamicMTGPlannerWithAtlas_50.0                 14.7829
#
#                                    Set Start and Goal Time  Success Rate  \
# Planner Name
# MTGTaskPlanner                                      0.0001       36.0000
# MTGTaskPlannerWithGMM                               0.0118       94.0000
# DynamicMTGTaskPlannerWithGMM_25.0                   1.3495       98.0000
# DynamicMTGTaskPlannerWithGMM_50.0                   1.3320       98.0000
# MTGTaskPlannerWithAtlas                             0.0121       90.0000
# DynamicMTGPlannerWithAtlas_25.0                     1.3995       92.0000
# DynamicMTGPlannerWithAtlas_50.0                     1.4238       96.0000
#
#                                    Total Number of Tasks  Total Planning Time
# Planner Name
# MTGTaskPlanner                                        50              33.9821
# MTGTaskPlannerWithGMM                                 50              11.7586
# DynamicMTGTaskPlannerWithGMM_25.0                     50               9.2817
# DynamicMTGTaskPlannerWithGMM_50.0                     50               7.7502
# MTGTaskPlannerWithAtlas                               50               9.2803
# DynamicMTGPlannerWithAtlas_25.0                       50               3.0983
# DynamicMTGPlannerWithAtlas_50.0                       50              12.8904

# %%
filepaths = ["..//task_set/open_bottle/result.json"]


for file_path in filepaths:
    print(file_path)
    result_data = read_json(file_path)
    planner_stats = {
                        planner_name: {
                            'num' : 0, 
                            'num_success' : [], 
                            'motion_planning_time' : [],
                            'task_planning_time' : [],
                            'updating_time' : [],
                            'solution_length' : [],
                            'num_attempts' : [],
                            'total_planning_time' : [],
                            'set_start_and_goal_time' : [],
                        } 

                     for planner_name in planner_names
                    }

    for d in result_data:
        if d['planner_name'] in planner_stats:
            dic = planner_stats[d['planner_name']]
            dic['num'] += 1
            dic['num_success'].append(d['success'] == "true")
            if d['success'] == "true":
                dic['motion_planning_time'].append(d['motion_planning_time'])
                dic['task_planning_time'].append(d['task_planning_time'])
                dic['total_planning_time'].append(d['total_planning_time'])
                dic['updating_time'].append(d['updating_time'])
                dic['solution_length'].append(d['solution_length'])
                dic['num_attempts'].append(d['num_attempts'])
                dic['set_start_and_goal_time'].append(d['set_start_and_goal_time'])

    output_dict = []
    for planner_name in planner_names:
        stats = planner_stats[planner_name]

        current_planner_eval_dict = {}
        current_planner_eval_dict["Planner Name"] = planner_name
        current_planner_eval_dict["Total Number of Tasks"] = len(stats['num_success'])
        current_planner_eval_dict["Success Rate"] = np.mean(stats['num_success']) * 100.0
        current_planner_eval_dict["Mean Task Planning Time"] = np.mean(np.array(stats['task_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean Motion Planning Time"] = np.mean(np.array(stats['motion_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Total Planning Time"] = np.mean(np.array(stats['total_planning_time']) )
        current_planner_eval_dict["Set Start and Goal Time"] = np.mean(np.array(stats['set_start_and_goal_time']) )
        current_planner_eval_dict["Mean Update time"] = np.mean(np.array(stats['updating_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean solution length"] = np.mean(np.array(stats['solution_length']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean number of attempts"] = np.mean((np.array(stats['num_attempts'])) )
        output_dict.append(current_planner_eval_dict)
    df = pd.DataFrame(output_dict).set_index('Planner Name')

    display(df)
# Out:
# ..//task_set/open_bottle/result.json
# /home/jiaming/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jiaming/.local/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                                    Mean Motion Planning Time  \
# Planner Name
# MTGTaskPlanner                                        5.5080
# MTGTaskPlannerWithGMM                                 4.9042
# DynamicMTGTaskPlannerWithGMM_25.0                     5.6376
# DynamicMTGTaskPlannerWithGMM_50.0                        nan
# MTGTaskPlannerWithAtlas                               4.7319
# DynamicMTGPlannerWithAtlas_25.0                          nan
# DynamicMTGPlannerWithAtlas_50.0                          nan
#
#                                    Mean Task Planning Time  Mean Update time  \
# Planner Name
# MTGTaskPlanner                                      0.8499            0.7035
# MTGTaskPlannerWithGMM                               0.7324            0.5466
# DynamicMTGTaskPlannerWithGMM_25.0                   0.1417            0.2001
# DynamicMTGTaskPlannerWithGMM_50.0                      nan               nan
# MTGTaskPlannerWithAtlas                             0.6816            0.5119
# DynamicMTGPlannerWithAtlas_25.0                        nan               nan
# DynamicMTGPlannerWithAtlas_50.0                        nan               nan
#
#                                    Mean number of attempts  \
# Planner Name
# MTGTaskPlanner                                     14.3000
# MTGTaskPlannerWithGMM                               4.6735
# DynamicMTGTaskPlannerWithGMM_25.0                  28.0000
# DynamicMTGTaskPlannerWithGMM_50.0                      nan
# MTGTaskPlannerWithAtlas                             3.9524
# DynamicMTGPlannerWithAtlas_25.0                        nan
# DynamicMTGPlannerWithAtlas_50.0                        nan
#
#                                    Mean solution length  \
# Planner Name
# MTGTaskPlanner                                   8.2983
# MTGTaskPlannerWithGMM                            7.9646
# DynamicMTGTaskPlannerWithGMM_25.0                4.1925
# DynamicMTGTaskPlannerWithGMM_50.0                   nan
# MTGTaskPlannerWithAtlas                         10.4508
# DynamicMTGPlannerWithAtlas_25.0                     nan
# DynamicMTGPlannerWithAtlas_50.0                     nan
#
#                                    Set Start and Goal Time  Success Rate  \
# Planner Name
# MTGTaskPlanner                                      0.0008       40.0000
# MTGTaskPlannerWithGMM                               0.0115       98.0000
# DynamicMTGTaskPlannerWithGMM_25.0                   3.4126      100.0000
# DynamicMTGTaskPlannerWithGMM_50.0                      nan           nan
# MTGTaskPlannerWithAtlas                             0.0111       84.0000
# DynamicMTGPlannerWithAtlas_25.0                        nan           nan
# DynamicMTGPlannerWithAtlas_50.0                        nan           nan
#
#                                    Total Number of Tasks  Total Planning Time
# Planner Name
# MTGTaskPlanner                                        50             104.6951
# MTGTaskPlannerWithGMM                                 50              31.8155
# DynamicMTGTaskPlannerWithGMM_25.0                      5             155.6299
# DynamicMTGTaskPlannerWithGMM_50.0                      0                  nan
# MTGTaskPlannerWithAtlas                               50              25.3063
# DynamicMTGPlannerWithAtlas_25.0                        0                  nan
# DynamicMTGPlannerWithAtlas_50.0                        0                  nan

# %%
filepaths = ["..//task_set/pour_water_seq/result.json"]


for file_path in filepaths:
    print(file_path)
    result_data = read_json(file_path)
    planner_stats = {
                        planner_name: {
                            'num' : 0, 
                            'num_success' : [], 
                            'motion_planning_time' : [],
                            'task_planning_time' : [],
                            'updating_time' : [],
                            'solution_length' : [],
                            'num_attempts' : [],
                            'total_planning_time' : [],
                            'set_start_and_goal_time' : [],
                        } 

                     for planner_name in planner_names
                    }

    for d in result_data:
        if d['planner_name'] in planner_stats:
            dic = planner_stats[d['planner_name']]
            dic['num'] += 1
            dic['num_success'].append(d['success'] == "true")
            if d['success'] == "true":
                dic['motion_planning_time'].append(d['motion_planning_time'])
                dic['task_planning_time'].append(d['task_planning_time'])
                dic['total_planning_time'].append(d['total_planning_time'])
                dic['updating_time'].append(d['updating_time'])
                dic['solution_length'].append(d['solution_length'])
                dic['num_attempts'].append(d['num_attempts'])
                dic['set_start_and_goal_time'].append(d['set_start_and_goal_time'])

    output_dict = []
    for planner_name in planner_names:
        stats = planner_stats[planner_name]

        current_planner_eval_dict = {}
        current_planner_eval_dict["Planner Name"] = planner_name
        current_planner_eval_dict["Total Number of Tasks"] = len(stats['num_success'])
        current_planner_eval_dict["Success Rate"] = np.mean(stats['num_success']) * 100.0
        current_planner_eval_dict["Mean Task Planning Time"] = np.mean(np.array(stats['task_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean Motion Planning Time"] = np.mean(np.array(stats['motion_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Total Planning Time"] = np.mean(np.array(stats['total_planning_time']) )
        current_planner_eval_dict["Set Start and Goal Time"] = np.mean(np.array(stats['set_start_and_goal_time']) )
        current_planner_eval_dict["Mean Update time"] = np.mean(np.array(stats['updating_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean solution length"] = np.mean(np.array(stats['solution_length']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean number of attempts"] = np.mean((np.array(stats['num_attempts'])) )
        output_dict.append(current_planner_eval_dict)
    df = pd.DataFrame(output_dict).set_index('Planner Name')

    display(df)
# Out:
# ..//task_set/pour_water_seq/result.json
#                                    Mean Motion Planning Time  \
# Planner Name
# MTGTaskPlanner                                        4.7186
# MTGTaskPlannerWithGMM                                 4.0616
# DynamicMTGTaskPlannerWithGMM_25.0                     4.3223
# DynamicMTGTaskPlannerWithGMM_50.0                     4.5064
# MTGTaskPlannerWithAtlas                               3.6373
# DynamicMTGPlannerWithAtlas_25.0                       4.0836
# DynamicMTGPlannerWithAtlas_50.0                       4.2023
#
#                                    Mean Task Planning Time  Mean Update time  \
# Planner Name
# MTGTaskPlanner                                      1.2233            0.5576
# MTGTaskPlannerWithGMM                               0.8897            1.2307
# DynamicMTGTaskPlannerWithGMM_25.0                   0.0299            0.4335
# DynamicMTGTaskPlannerWithGMM_50.0                   0.0018            0.4263
# MTGTaskPlannerWithAtlas                             1.1654            1.0912
# DynamicMTGPlannerWithAtlas_25.0                     0.0893            0.4623
# DynamicMTGPlannerWithAtlas_50.0                     0.0684            0.4404
#
#                                    Mean number of attempts  \
# Planner Name
# MTGTaskPlanner                                      5.2000
# MTGTaskPlannerWithGMM                               1.7400
# DynamicMTGTaskPlannerWithGMM_25.0                   2.6800
# DynamicMTGTaskPlannerWithGMM_50.0                   3.1000
# MTGTaskPlannerWithAtlas                             1.8000
# DynamicMTGPlannerWithAtlas_25.0                     2.7200
# DynamicMTGPlannerWithAtlas_50.0                     3.5400
#
#                                    Mean solution length  \
# Planner Name
# MTGTaskPlanner                                  16.7975
# MTGTaskPlannerWithGMM                           16.3628
# DynamicMTGTaskPlannerWithGMM_25.0               15.2710
# DynamicMTGTaskPlannerWithGMM_50.0               15.7724
# MTGTaskPlannerWithAtlas                         16.3336
# DynamicMTGPlannerWithAtlas_25.0                 14.0533
# DynamicMTGPlannerWithAtlas_50.0                 12.8493
#
#                                    Set Start and Goal Time  Success Rate  \
# Planner Name
# MTGTaskPlanner                                      0.0093      100.0000
# MTGTaskPlannerWithGMM                               0.0122      100.0000
# DynamicMTGTaskPlannerWithGMM_25.0                   6.1597      100.0000
# DynamicMTGTaskPlannerWithGMM_50.0                   6.1322      100.0000
# MTGTaskPlannerWithAtlas                             0.0128      100.0000
# DynamicMTGPlannerWithAtlas_25.0                     6.2484      100.0000
# DynamicMTGPlannerWithAtlas_50.0                     6.4593      100.0000
#
#                                    Total Number of Tasks  Total Planning Time
# Planner Name
# MTGTaskPlanner                                        50              37.1212
# MTGTaskPlannerWithGMM                                 50              11.7650
# DynamicMTGTaskPlannerWithGMM_25.0                     50              14.2608
# DynamicMTGTaskPlannerWithGMM_50.0                     50              15.2547
# MTGTaskPlannerWithAtlas                               50              11.5964
# DynamicMTGPlannerWithAtlas_25.0                       50              13.3870
# DynamicMTGPlannerWithAtlas_50.0                       50              17.9758

# %%
filepaths = ["..//task_set/shelf/result.json"]


for file_path in filepaths:
    print(file_path)
    result_data = read_json(file_path)
    planner_stats = {
                        planner_name: {
                            'num' : 0, 
                            'num_success' : [], 
                            'motion_planning_time' : [],
                            'task_planning_time' : [],
                            'updating_time' : [],
                            'solution_length' : [],
                            'num_attempts' : [],
                            'total_planning_time' : [],
                            'set_start_and_goal_time' : [],
                        } 

                     for planner_name in planner_names
                    }

    for d in result_data:
        if d['planner_name'] in planner_stats:
            dic = planner_stats[d['planner_name']]
            dic['num'] += 1
            dic['num_success'].append(d['success'] == "true")
            if d['success'] == "true":
                dic['motion_planning_time'].append(d['motion_planning_time'])
                dic['task_planning_time'].append(d['task_planning_time'])
                dic['total_planning_time'].append(d['total_planning_time'])
                dic['updating_time'].append(d['updating_time'])
                dic['solution_length'].append(d['solution_length'])
                dic['num_attempts'].append(d['num_attempts'])
                dic['set_start_and_goal_time'].append(d['set_start_and_goal_time'])

    output_dict = []
    for planner_name in planner_names:
        stats = planner_stats[planner_name]

        current_planner_eval_dict = {}
        current_planner_eval_dict["Planner Name"] = planner_name
        current_planner_eval_dict["Total Number of Tasks"] = len(stats['num_success'])
        current_planner_eval_dict["Success Rate"] = np.mean(stats['num_success']) * 100.0
        current_planner_eval_dict["Mean Task Planning Time"] = np.mean(np.array(stats['task_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean Motion Planning Time"] = np.mean(np.array(stats['motion_planning_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Total Planning Time"] = np.mean(np.array(stats['total_planning_time']) )
        current_planner_eval_dict["Set Start and Goal Time"] = np.mean(np.array(stats['set_start_and_goal_time']) )
        current_planner_eval_dict["Mean Update time"] = np.mean(np.array(stats['updating_time']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean solution length"] = np.mean(np.array(stats['solution_length']) / (np.array(stats['num_attempts'])) )
        current_planner_eval_dict["Mean number of attempts"] = np.mean((np.array(stats['num_attempts'])) )
        output_dict.append(current_planner_eval_dict)
    df = pd.DataFrame(output_dict).set_index('Planner Name')

    display(df)
# Out:
# ..//task_set/shelf/result.json
#                                    Mean Motion Planning Time  \
# Planner Name
# MTGTaskPlanner                                        5.2146
# MTGTaskPlannerWithGMM                                 5.9381
# DynamicMTGTaskPlannerWithGMM_25.0                     6.5506
# DynamicMTGTaskPlannerWithGMM_50.0                     6.4967
# MTGTaskPlannerWithAtlas                               6.6645
# DynamicMTGPlannerWithAtlas_25.0                       7.0462
# DynamicMTGPlannerWithAtlas_50.0                       6.6954
#
#                                    Mean Task Planning Time  Mean Update time  \
# Planner Name
# MTGTaskPlanner                                      0.1886            0.1951
# MTGTaskPlannerWithGMM                               0.3976            0.8273
# DynamicMTGTaskPlannerWithGMM_25.0                   0.0265            0.3097
# DynamicMTGTaskPlannerWithGMM_50.0                   0.0275            0.3079
# MTGTaskPlannerWithAtlas                             0.4319            0.8665
# DynamicMTGPlannerWithAtlas_25.0                     0.0010            0.3191
# DynamicMTGPlannerWithAtlas_50.0                     0.0010            0.2982
#
#                                    Mean number of attempts  \
# Planner Name
# MTGTaskPlanner                                     13.6970
# MTGTaskPlannerWithGMM                               2.4490
# DynamicMTGTaskPlannerWithGMM_25.0                   2.1600
# DynamicMTGTaskPlannerWithGMM_50.0                   2.3400
# MTGTaskPlannerWithAtlas                             1.4600
# DynamicMTGPlannerWithAtlas_25.0                     1.1800
# DynamicMTGPlannerWithAtlas_50.0                     1.1600
#
#                                    Mean solution length  \
# Planner Name
# MTGTaskPlanner                                  11.6718
# MTGTaskPlannerWithGMM                           19.0389
# DynamicMTGTaskPlannerWithGMM_25.0               21.7487
# DynamicMTGTaskPlannerWithGMM_50.0               20.9628
# MTGTaskPlannerWithAtlas                         22.1314
# DynamicMTGPlannerWithAtlas_25.0                 25.8940
# DynamicMTGPlannerWithAtlas_50.0                 27.0186
#
#                                    Set Start and Goal Time  Success Rate  \
# Planner Name
# MTGTaskPlanner                                      0.0004       66.0000
# MTGTaskPlannerWithGMM                               0.0120       98.0000
# DynamicMTGTaskPlannerWithGMM_25.0                   2.3725      100.0000
# DynamicMTGTaskPlannerWithGMM_50.0                   2.2897      100.0000
# MTGTaskPlannerWithAtlas                             0.0136      100.0000
# DynamicMTGPlannerWithAtlas_25.0                     2.4004      100.0000
# DynamicMTGPlannerWithAtlas_50.0                     2.2874      100.0000
#
#                                    Total Number of Tasks  Total Planning Time
# Planner Name
# MTGTaskPlanner                                        50              91.8334
# MTGTaskPlannerWithGMM                                 50              18.0543
# DynamicMTGTaskPlannerWithGMM_25.0                     50              14.0029
# DynamicMTGTaskPlannerWithGMM_50.0                     50              14.5831
# MTGTaskPlannerWithAtlas                               50              11.4756
# DynamicMTGPlannerWithAtlas_25.0                       50               8.6243
# DynamicMTGPlannerWithAtlas_50.0                       50               7.8690
